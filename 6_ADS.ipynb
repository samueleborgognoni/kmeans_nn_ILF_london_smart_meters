# %% [markdown]
# <a href="https://colab.research.google.com/github/samueleborgognoni/kmeans_nn_ILF_london_smart_meters/blob/main/6_ADS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Anomaly Detection System

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.decomposition import PCA
from sklearn.svm import OneClassSVM
from sklearn.preprocessing import StandardScaler

# %%
from google.colab import drive
drive.mount('/content/drive')

drive_folder_path = '/content/drive/MyDrive/-Career📚/_UNIVERSITY/__Macchine_ed_azionamenti_elettrici/_Progetto_MAE/mae_proj/'
# Out:
# Mounted at /content/drive

# %%
# Import previously extracted data for CLUSTER 0
X_ilf_train = pd.read_csv(drive_folder_path + 'data/X_ilf_train.csv')
X_ilf_test = pd.read_csv(drive_folder_path + 'data/X_ilf_test.csv')
y_ilf_train = pd.read_csv(drive_folder_path + 'data/y_ilf_train.csv', index_col=0)
y_ilf_test = pd.read_csv(drive_folder_path + 'data/y_ilf_test.csv', index_col=0)

# Import the attacked data for the 10 meters
y_10_ilf_test_attacked = pd.read_csv(drive_folder_path + 'data/y_10_ilf_test_attacked.csv')

# %%
# Insert the attacked data of 10 meters into the full test set
y_ilf_test_attacked = y_ilf_test.copy()
y_ilf_test_attacked = y_ilf_test_attacked.set_index(['tstp','LCLid'])
y_10_attacked_indexed = y_10_ilf_test_attacked.set_index(['tstp','LCLid'])

y_ilf_test_attacked.update(y_10_attacked_indexed)

y_ilf_test_attacked = y_ilf_test_attacked.reset_index()

# %%
# Mask of different values (attacks)
diff_mask = y_ilf_test_attacked['energy(kWh)'] != y_ilf_test['energy(kWh)']
print(diff_mask.sum())
print(y_ilf_test_attacked[diff_mask].head())
# Out:
# 15714
#                       tstp      LCLid  energy(kWh)
# 14806  2013-06-28 11:00:00  MAC000342       0.0399
# 14807  2013-06-28 12:00:00  MAC000342       0.0245
# 14808  2013-06-28 14:00:00  MAC000342       0.0346
# 14809  2013-06-28 15:00:00  MAC000342       0.0374
# 14810  2013-06-28 17:00:00  MAC000342       0.0424

# %%
# Set right indexes
y_test_attacked_meter = y_ilf_test_attacked.set_index(['tstp','LCLid'])
y_test_meter = y_ilf_test.set_index(['tstp','LCLid'])
y_train_meter = y_ilf_train.set_index(['tstp','LCLid'])

X_train_meter = X_ilf_train.drop(columns=['lag_1', 'lag_24', 'hour_sin','day_sin','month_sin']).set_index(['tstp','LCLid'])
X_test_meter = X_ilf_test.drop(columns=['lag_1', 'lag_24', 'hour_sin','day_sin','month_sin']).set_index(['tstp','LCLid'])

# %%
# Concat X and y df, since OCSVM is (semi-)unsupervised method and needs onlt one dataset
df_train_meter = pd.concat([X_train_meter, y_train_meter], axis=1)
df_test_meter = pd.concat([X_test_meter, y_test_attacked_meter], axis=1)

df_true_y_values_meter = pd.concat([X_test_meter, y_test_meter], axis=1)

# %%
print(df_test_meter.shape)
print(df_true_y_values_meter.shape)
# Out:
# (605931, 2)
# (605931, 2)

# %% [markdown]
# ### Feature extraction

# %%
from scipy.stats import kurtosis

def extract_features_adc(df_meter, window=3):
    """
    Extract statistical features from 'energy(kWh)' per meter (LCLid)
    over a rolling window.
    """

    # Group by meter + rolling window
    s = df_meter.groupby(level='LCLid')['energy(kWh)']
    s_roll = s.rolling(window)

    # Rolling statistics
    df_meter[f'mean_{window}'] = s_roll.mean().reset_index(level=0, drop=True)
    df_meter[f'std_{window}'] = s_roll.std().reset_index(level=0, drop=True)

    # RMS
    df_meter[f'rms_{window}'] = np.sqrt(
        s_roll.apply(lambda x: np.mean(x**2), raw=True).reset_index(level=0, drop=True)
    )

    # Mean absolute and max absolute
    df_meter[f'mean_abs_{window}'] = s_roll.apply(lambda x: np.mean(np.abs(x)), raw=True).reset_index(level=0, drop=True)
    df_meter[f'max_abs_{window}'] = s_roll.apply(lambda x: np.max(np.abs(x)), raw=True).reset_index(level=0, drop=True)

    # Kurtosis
    # df_meter[f'kurtosis_{window}'] = s_roll.apply(lambda x: kurtosis(x), raw=True).reset_index(level=0, drop=True)

    # Derived factors
    df_meter[f'crest_factor_{window}'] = df_meter[f'max_abs_{window}'] / df_meter[f'rms_{window}']
    df_meter[f'impulse_factor_{window}'] = df_meter[f'max_abs_{window}'] / df_meter[f'mean_abs_{window}']
    df_meter[f'shape_factor_{window}'] = df_meter[f'rms_{window}'] / df_meter[f'mean_abs_{window}']

    # Drop NaN caused by rolling window
    df_meter.dropna(inplace=True)

    return df_meter.drop(columns=[f'mean_abs_{window}',f'max_abs_{window}'])

# %%
# extract features
extracted_df_train_meter = extract_features_adc(df_train_meter, window=48)
extracted_df_test_meter = extract_features_adc(df_test_meter, window=48)

extracted_df_true_y_values_meter = extract_features_adc(df_true_y_values_meter, window=48)

# %%
# Drop individual energy load "energy(kWh)"
_df_test_meter = extracted_df_test_meter.drop(columns='energy(kWh)')
_df_train_meter = extracted_df_train_meter.drop(columns='energy(kWh)')
_df_true_y_values_meter = extracted_df_true_y_values_meter.drop(columns='energy(kWh)')

_df_train_meter
# Out:
#                                energy_mean_cluster   mean_48    std_48  \
# tstp                LCLid
# 2013-02-02 05:00:00 MAC000002             0.219363  0.200333  0.002861
# 2013-02-02 06:00:00 MAC000002             0.264186  0.200250  0.002899
# 2013-02-02 08:00:00 MAC000002             0.463877  0.200125  0.002994
# 2013-02-03 03:00:00 MAC000002             0.239882  0.200146  0.003011
# 2013-02-03 04:00:00 MAC000002             0.220407  0.200208  0.003059
# ...                                            ...       ...       ...
# 2013-06-28 04:00:00 MAC005523             0.190265  0.356250  0.283479
# 2013-06-28 05:00:00 MAC005523             0.218708  0.345958  0.282592
# 2013-06-28 06:00:00 MAC005523             0.325461  0.346792  0.282178
# 2013-06-28 07:00:00 MAC005523             0.387579  0.347917  0.281687
# 2013-06-28 08:00:00 MAC005523             0.419124  0.345062  0.282524
#
#                                  rms_48  crest_factor_48  impulse_factor_48  \
# tstp                LCLid
# 2013-02-02 05:00:00 MAC000002  0.200353         1.033175           1.033278
# 2013-02-02 06:00:00 MAC000002  0.200271         1.033602           1.033708
# 2013-02-02 08:00:00 MAC000002  0.200147         1.034240           1.034354
# 2013-02-03 03:00:00 MAC000002  0.200168         1.034131           1.034246
# 2013-02-03 04:00:00 MAC000002  0.200231         1.033805           1.033923
# ...                                 ...              ...                ...
# 2013-06-28 04:00:00 MAC005523  0.453432         3.334570           4.244211
# 2013-06-28 05:00:00 MAC005523  0.444839         3.398984           4.370469
# 2013-06-28 06:00:00 MAC005523  0.445230         3.395996           4.359966
# 2013-06-28 07:00:00 MAC005523  0.445803         3.391629           4.345868
# 2013-06-28 08:00:00 MAC005523  0.444100         3.404636           4.381815
#
#                                shape_factor_48
# tstp                LCLid
# 2013-02-02 05:00:00 MAC000002         1.000100
# 2013-02-02 06:00:00 MAC000002         1.000103
# 2013-02-02 08:00:00 MAC000002         1.000110
# 2013-02-03 03:00:00 MAC000002         1.000111
# 2013-02-03 04:00:00 MAC000002         1.000114
# ...                                        ...
# 2013-06-28 04:00:00 MAC005523         1.272791
# 2013-06-28 05:00:00 MAC005523         1.285816
# 2013-06-28 06:00:00 MAC005523         1.283855
# 2013-06-28 07:00:00 MAC005523         1.281351
# 2013-06-28 08:00:00 MAC005523         1.287014
#
# [977515 rows x 7 columns]

# %% [markdown]
# ### OC-SVM Anomaly Detection algorithm

# %%
# TRAIN AND TEST OC-OSV ITERATIVELY FOR EACH METER

all_preds = []
all_indices = []

train_ids = set(_df_train_meter.index.get_level_values('LCLid'))
test_ids = set(_df_test_meter.index.get_level_values('LCLid'))

_ids = train_ids.intersection(test_ids)

# Pick these IDs to detect only in the 10 attacked meters:
#_ids = ['MAC004029','MAC000342', 'MAC002517', 'MAC003558', 'MAC001070', 'MAC002606', 'MAC003719', 'MAC003502', 'MAC002621', 'MAC001166']

for meter_id in _ids:

    print(f"Processing meter: {meter_id}")

    # SELECT DATA PER METER ---
    train_meter = _df_train_meter.xs(meter_id, level='LCLid')
    test_meter = _df_test_meter.xs(meter_id, level='LCLid')
    true_meter = _df_true_y_values_meter.xs(meter_id, level='LCLid')


    # Scale
    scaler = StandardScaler()
    train_scaled = scaler.fit_transform(train_meter)
    test_scaled = scaler.transform(test_meter)
    true_scaled = scaler.transform(true_meter)

    # PCA
    pca = PCA(n_components = 4)
    train_pca = pca.fit_transform(train_scaled)
    test_pca = pca.transform(test_scaled)
    true_pca = pca.transform(true_scaled)

    print(f"Meter {meter_id}")
    print("Explained variance ratio:", pca.explained_variance_ratio_)
    print("Cumulative explained variance:", pca.explained_variance_ratio_.sum())

    # TRAIN OCSVM
    ocsvm = OneClassSVM(nu=0.05, kernel='rbf', gamma='scale')
    ocsvm.fit(train_pca)

    # PREDICT
    y_pred_meter = ocsvm.predict(test_pca)

    # save
    idx = pd.MultiIndex.from_arrays(
    [test_meter.index, [meter_id]*len(test_meter)],
    names=['tstp', 'LCLid'])

    all_preds.append(pd.Series(y_pred_meter, index=idx))
# Out:
# Processing meter: MAC001420
# Meter MAC001420
# Explained variance ratio: [0.40615701 0.35697536 0.14237219 0.07254426]
# Cumulative explained variance: 0.9780488218076159
# Processing meter: MAC003958
# Meter MAC003958
# Explained variance ratio: [0.49543052 0.33672068 0.13461856 0.03179825]
# Cumulative explained variance: 0.9985680110393702
# Processing meter: MAC002358
# Meter MAC002358
# Explained variance ratio: [0.55840892 0.24909728 0.14252166 0.04812022]
# Cumulative explained variance: 0.9981480885224907
# Processing meter: MAC000342
# Meter MAC000342
# Explained variance ratio: [0.48144483 0.2765871  0.13047224 0.09513177]
# Cumulative explained variance: 0.983635941813208
# Processing meter: MAC002829
# Meter MAC002829
# Explained variance ratio: [0.5130631  0.31347424 0.13247497 0.03990468]
# Cumulative explained variance: 0.9989169936859066
# Processing meter: MAC005134
# Meter MAC005134
# Explained variance ratio: [0.46182707 0.33901748 0.13160876 0.06405476]
# Cumulative explained variance: 0.9965080720303015
# Processing meter: MAC004714
# Meter MAC004714
# Explained variance ratio: [0.52011028 0.29130415 0.13141083 0.05437469]
# Cumulative explained variance: 0.997199961038698
# Processing meter: MAC005367
# Meter MAC005367
# Explained variance ratio: [0.46808104 0.32869932 0.13960917 0.05862107]
# Cumulative explained variance: 0.9950105994448225
# Processing meter: MAC001518
# Meter MAC001518
# Explained variance ratio: [0.43703431 0.37060622 0.13691522 0.0489679 ]
# Cumulative explained variance: 0.9935236507743753
# Processing meter: MAC001580
# Meter MAC001580
# Explained variance ratio: [0.42501236 0.35495979 0.14248066 0.06701142]
# Cumulative explained variance: 0.9894642416374307
# Processing meter: MAC004287
# Meter MAC004287
# Explained variance ratio: [0.43980264 0.36299141 0.1379457  0.05471436]
# Cumulative explained variance: 0.9954541081187058
# Processing meter: MAC003843
# Meter MAC003843
# Explained variance ratio: [0.45435629 0.33690368 0.14093916 0.06656322]
# Cumulative explained variance: 0.9987623486047097
# Processing meter: MAC004178
# Meter MAC004178
# Explained variance ratio: [0.54554229 0.28302076 0.13769977 0.02877169]
# Cumulative explained variance: 0.995034502921665
# Processing meter: MAC005375
# Meter MAC005375
# Explained variance ratio: [0.48720989 0.32963532 0.13712396 0.04238467]
# Cumulative explained variance: 0.9963538305234958
# Processing meter: MAC004647
# Meter MAC004647
# Explained variance ratio: [0.46331797 0.34848482 0.14120829 0.04570666]
# Cumulative explained variance: 0.9987177460125471
# Processing meter: MAC002083
# Meter MAC002083
# Explained variance ratio: [0.48144254 0.35608359 0.13957221 0.02072012]
# Cumulative explained variance: 0.9978184612185009
# Processing meter: MAC004529
# Meter MAC004529
# Explained variance ratio: [0.54678859 0.26565253 0.14070945 0.04481888]
# Cumulative explained variance: 0.997969454888171
# Processing meter: MAC002617
# Meter MAC002617
# Explained variance ratio: [0.53860347 0.26077405 0.14191496 0.05321237]
# Cumulative explained variance: 0.9945048534712033
# Processing meter: MAC003719
# Meter MAC003719
# Explained variance ratio: [0.47558839 0.35462016 0.1339987  0.03408662]
# Cumulative explained variance: 0.9982938661882375
# Processing meter: MAC003229
# Meter MAC003229
# Explained variance ratio: [0.4413065  0.35903631 0.13872083 0.05760954]
# Cumulative explained variance: 0.9966731816809566
# Processing meter: MAC005365
# Meter MAC005365
# Explained variance ratio: [0.59227494 0.20014538 0.1427606  0.05771167]
# Cumulative explained variance: 0.9928925914146368
# Processing meter: MAC001070
# Meter MAC001070
# Explained variance ratio: [0.62116806 0.21399002 0.12690432 0.03133684]
# Cumulative explained variance: 0.993399242537262
# Processing meter: MAC004567
# Meter MAC004567
# Explained variance ratio: [0.59750834 0.247183   0.12398336 0.03000374]
# Cumulative explained variance: 0.9986784305540372
# Processing meter: MAC002719
# Meter MAC002719
# Explained variance ratio: [0.45589603 0.33636219 0.13589513 0.06644722]
# Cumulative explained variance: 0.9946005725928506
# Processing meter: MAC001239
# Meter MAC001239
# Explained variance ratio: [0.61595027 0.20039675 0.1412167  0.03965514]
# Cumulative explained variance: 0.997218856860868
# Processing meter: MAC003558
# Meter MAC003558
# Explained variance ratio: [0.52275362 0.29187589 0.12831184 0.05600977]
# Cumulative explained variance: 0.9989511264000177
# Processing meter: MAC003805
# Meter MAC003805
# Explained variance ratio: [0.5654503  0.25372772 0.13622916 0.04249103]
# Cumulative explained variance: 0.9978982172895032
# Processing meter: MAC002563
# Meter MAC002563
# Explained variance ratio: [0.57928927 0.25049301 0.13180413 0.03747606]
# Cumulative explained variance: 0.9990624626822878
# Processing meter: MAC005387
# Meter MAC005387
# Explained variance ratio: [0.43500191 0.37208693 0.14126467 0.0476688 ]
# Cumulative explained variance: 0.9960223037008347
# Processing meter: MAC004006
# Meter MAC004006
# Explained variance ratio: [0.45761072 0.37759547 0.13095371 0.03133526]
# Cumulative explained variance: 0.9974951635023429
# Processing meter: MAC001410
# Meter MAC001410
# Explained variance ratio: [0.56863939 0.26815647 0.13948942 0.02179413]
# Cumulative explained variance: 0.9980794064487658
# Processing meter: MAC004832
# Meter MAC004832
# Explained variance ratio: [0.61058618 0.2098463  0.13474714 0.04137533]
# Cumulative explained variance: 0.9965549526523377
# Processing meter: MAC002138
# Meter MAC002138
# Explained variance ratio: [0.53688818 0.29223893 0.13041592 0.03864876]
# Cumulative explained variance: 0.9981917886711489
# Processing meter: MAC003286
# Meter MAC003286
# Explained variance ratio: [0.45317033 0.35269515 0.14178956 0.0496604 ]
# Cumulative explained variance: 0.9973154420596885
# Processing meter: MAC003502
# Meter MAC003502
# Explained variance ratio: [0.49181414 0.32248546 0.13222622 0.05278333]
# Cumulative explained variance: 0.9993091536836418
# Processing meter: MAC003173
# Meter MAC003173
# Explained variance ratio: [0.59707915 0.24971466 0.12317161 0.02921843]
# Cumulative explained variance: 0.9991838522706562
# Processing meter: MAC003225
# Meter MAC003225
# Explained variance ratio: [0.52629138 0.25653336 0.14060494 0.07196814]
# Cumulative explained variance: 0.995397817403727
# Processing meter: MAC001867
# Meter MAC001867
# Explained variance ratio: [0.44341285 0.3357077  0.1374161  0.07005441]
# Cumulative explained variance: 0.9865910676843912
# Processing meter: MAC001819
# Meter MAC001819
# Explained variance ratio: [0.5358883  0.25557428 0.13038195 0.05747584]
# Cumulative explained variance: 0.979320377402239
# Processing meter: MAC005254
# Meter MAC005254
# Explained variance ratio: [0.50115406 0.32578237 0.13668257 0.03266693]
# Cumulative explained variance: 0.9962859331439328
# Processing meter: MAC001612
# Meter MAC001612
# Explained variance ratio: [0.43858776 0.35966108 0.14016528 0.05890841]
# Cumulative explained variance: 0.997322527576765
# Processing meter: MAC004111
# Meter MAC004111
# Explained variance ratio: [0.48182703 0.30962383 0.13824937 0.06612552]
# Cumulative explained variance: 0.9958257561699193
# Processing meter: MAC005506
# Meter MAC005506
# Explained variance ratio: [0.50135565 0.3264306  0.13253374 0.03861723]
# Cumulative explained variance: 0.9989372215419076
# Processing meter: MAC003184
# Meter MAC003184
# Explained variance ratio: [0.48257588 0.29670181 0.14128104 0.07530282]
# Cumulative explained variance: 0.9958615485103794
# Processing meter: MAC004628
# Meter MAC004628
# Explained variance ratio: [0.58058026 0.26498342 0.1236671  0.02920177]
# Cumulative explained variance: 0.9984325350113692
# Processing meter: MAC003844
# Meter MAC003844
# Explained variance ratio: [0.50735417 0.29410386 0.14049091 0.05325825]
# Cumulative explained variance: 0.9952071970104143
# Processing meter: MAC003482
# Meter MAC003482
# Explained variance ratio: [0.64308109 0.19982681 0.1343901  0.0220909 ]
# Cumulative explained variance: 0.9993888981981429
# Processing meter: MAC001873
# Meter MAC001873
# Explained variance ratio: [0.53167785 0.29883833 0.12747337 0.04034482]
# Cumulative explained variance: 0.9983343633817013
# Processing meter: MAC003536
# Meter MAC003536
# Explained variance ratio: [0.47621867 0.30568674 0.13981902 0.07608988]
# Cumulative explained variance: 0.9978143004564612
# Processing meter: MAC002606
# Meter MAC002606
# Explained variance ratio: [0.40857816 0.39480666 0.14119979 0.05340604]
# Cumulative explained variance: 0.997990651703132
# Processing meter: MAC004367
# Meter MAC004367
# Explained variance ratio: [0.56610323 0.25772436 0.13650088 0.03493356]
# Cumulative explained variance: 0.9952620256214185
# Processing meter: MAC004928
# Meter MAC004928
# Explained variance ratio: [0.49746516 0.3399013  0.13311272 0.02618755]
# Cumulative explained variance: 0.9966667359363679
# Processing meter: MAC001232
# Meter MAC001232
# Explained variance ratio: [0.42433844 0.34482365 0.13593478 0.08263252]
# Cumulative explained variance: 0.9877293872485944
# Processing meter: MAC004990
# Meter MAC004990
# Explained variance ratio: [0.55052216 0.27447105 0.133654   0.04108346]
# Cumulative explained variance: 0.9997306757151658
# Processing meter: MAC002621
# Meter MAC002621
# Explained variance ratio: [0.55541276 0.27653823 0.13800933 0.02898066]
# Cumulative explained variance: 0.9989409846538775
# Processing meter: MAC005392
# Meter MAC005392
# Explained variance ratio: [0.54267882 0.26392767 0.13934457 0.04607467]
# Cumulative explained variance: 0.9920257261194472
# Processing meter: MAC005331
# Meter MAC005331
# Explained variance ratio: [0.40339558 0.36640717 0.13890982 0.05455801]
# Cumulative explained variance: 0.9632705773347036
# Processing meter: MAC004475
# Meter MAC004475
# Explained variance ratio: [0.4938587  0.31741492 0.13861507 0.04653689]
# Cumulative explained variance: 0.9964255799073715
# Processing meter: MAC002218
# Meter MAC002218
# Explained variance ratio: [0.55019534 0.22509571 0.12663174 0.05534322]
# Cumulative explained variance: 0.9572660059513806
# Processing meter: MAC005160
# Meter MAC005160
# Explained variance ratio: [0.45533953 0.36340011 0.13180146 0.04875221]
# Cumulative explained variance: 0.9992933029952618
# Processing meter: MAC002005
# Meter MAC002005
# Explained variance ratio: [0.41015243 0.34047595 0.1376137  0.07805382]
# Cumulative explained variance: 0.9662959091407268
# Processing meter: MAC003863
# Meter MAC003863
# Explained variance ratio: [0.47822654 0.34077651 0.136875   0.04213351]
# Cumulative explained variance: 0.998011571044187
# Processing meter: MAC002622
# Meter MAC002622
# Explained variance ratio: [0.54450031 0.26854064 0.13481733 0.0475063 ]
# Cumulative explained variance: 0.995364585310652
# Processing meter: MAC005403
# Meter MAC005403
# Explained variance ratio: [0.48033017 0.32676998 0.14151453 0.04860246]
# Cumulative explained variance: 0.9972171312285837
# Processing meter: MAC003782
# Meter MAC003782
# Explained variance ratio: [0.52655416 0.28384519 0.12750102 0.06159342]
# Cumulative explained variance: 0.9994937894145773
# Processing meter: MAC002567
# Meter MAC002567
# Explained variance ratio: [0.42507656 0.36892313 0.14232848 0.05885278]
# Cumulative explained variance: 0.9951809557189049
# Processing meter: MAC002884
# Meter MAC002884
# Explained variance ratio: [0.40947739 0.35695869 0.13686387 0.07940146]
# Cumulative explained variance: 0.9827014172168018
# Processing meter: MAC001539
# Meter MAC001539
# Explained variance ratio: [0.59486265 0.22104101 0.14042517 0.03837632]
# Cumulative explained variance: 0.9947051532146867
# Processing meter: MAC000797
# Meter MAC000797
# Explained variance ratio: [0.52991695 0.27321274 0.13137281 0.06047907]
# Cumulative explained variance: 0.9949815593777416
# Processing meter: MAC001800
# Meter MAC001800
# Explained variance ratio: [0.57108549 0.22670982 0.12798574 0.05517491]
# Cumulative explained variance: 0.9809559701991161
# Processing meter: MAC002683
# Meter MAC002683
# Explained variance ratio: [0.41833317 0.34112205 0.14114527 0.08697653]
# Cumulative explained variance: 0.9875770199231397
# Processing meter: MAC002859
# Meter MAC002859
# Explained variance ratio: [0.51022328 0.31075781 0.12908961 0.04659086]
# Cumulative explained variance: 0.9966615583283145
# Processing meter: MAC004945
# Meter MAC004945
# Explained variance ratio: [0.51773518 0.30522602 0.13187447 0.04290889]
# Cumulative explained variance: 0.9977445666593917
# Processing meter: MAC000983
# Meter MAC000983
# Explained variance ratio: [0.44990403 0.35451079 0.13354536 0.04351496]
# Cumulative explained variance: 0.981475135821048
# Processing meter: MAC001352
# Meter MAC001352
# Explained variance ratio: [0.47484592 0.32092822 0.13504289 0.06448358]
# Cumulative explained variance: 0.9953006159094975
# Processing meter: MAC002199
# Meter MAC002199
# Explained variance ratio: [0.70088796 0.14882796 0.12434034 0.02414688]
# Cumulative explained variance: 0.9982031310562652
# Processing meter: MAC001717
# Meter MAC001717
# Explained variance ratio: [0.49897535 0.26729361 0.1391896  0.06231104]
# Cumulative explained variance: 0.9677696039892374
# Processing meter: MAC004447
# Meter MAC004447
# Explained variance ratio: [0.62481682 0.21080824 0.13712896 0.02608392]
# Cumulative explained variance: 0.9988379426468174
# Processing meter: MAC004590
# Meter MAC004590
# Explained variance ratio: [0.44133106 0.36850456 0.13772623 0.05121817]
# Cumulative explained variance: 0.9987800178317352
# Processing meter: MAC002201
# Meter MAC002201
# Explained variance ratio: [0.43725984 0.40378134 0.12106105 0.03650595]
# Cumulative explained variance: 0.9986081786700969
# Processing meter: MAC000194
# Meter MAC000194
# Explained variance ratio: [0.74384538 0.13881299 0.10941648 0.00669277]
# Cumulative explained variance: 0.9987676136822614
# Processing meter: MAC002510
# Meter MAC002510
# Explained variance ratio: [0.43322106 0.38818761 0.14080232 0.03293801]
# Cumulative explained variance: 0.9951490012330205
# Processing meter: MAC003851
# Meter MAC003851
# Explained variance ratio: [0.56055577 0.24026722 0.12969591 0.06893689]
# Cumulative explained variance: 0.999455788300647
# Processing meter: MAC002070
# Meter MAC002070
# Explained variance ratio: [0.44446174 0.3691952  0.12752799 0.0565097 ]
# Cumulative explained variance: 0.9976946328261393
# Processing meter: MAC003252
# Meter MAC003252
# Explained variance ratio: [0.40564879 0.38283199 0.13637111 0.06860397]
# Cumulative explained variance: 0.9934558661867331
# Processing meter: MAC001166
# Meter MAC001166
# Explained variance ratio: [0.43443384 0.39088216 0.11972043 0.05378075]
# Cumulative explained variance: 0.9988171725572799
# Processing meter: MAC002134
# Meter MAC002134
# Explained variance ratio: [0.63498994 0.17907847 0.13317846 0.04924494]
# Cumulative explained variance: 0.9964918208301216
# Processing meter: MAC002497
# Meter MAC002497
# Explained variance ratio: [0.44762436 0.36366813 0.14104219 0.04447132]
# Cumulative explained variance: 0.9968059977084813
# Processing meter: MAC003400
# Meter MAC003400
# Explained variance ratio: [0.50224334 0.28163685 0.13355456 0.08182112]
# Cumulative explained variance: 0.9992558723403493
# Processing meter: MAC002929
# Meter MAC002929
# Explained variance ratio: [0.47357302 0.3067305  0.13050638 0.07573545]
# Cumulative explained variance: 0.9865453482961026
# Processing meter: MAC003220
# Meter MAC003220
# Explained variance ratio: [0.51991114 0.26728577 0.13531414 0.06808348]
# Cumulative explained variance: 0.9905945425890346
# Processing meter: MAC002599
# Meter MAC002599
# Explained variance ratio: [0.54146048 0.27416913 0.13470482 0.04774287]
# Cumulative explained variance: 0.9980772984268182
# Processing meter: MAC002233
# Meter MAC002233
# Explained variance ratio: [0.51193811 0.29190252 0.12737135 0.05728997]
# Cumulative explained variance: 0.9885019495251872
# Processing meter: MAC000300
# Meter MAC000300
# Explained variance ratio: [0.55687514 0.28552642 0.1320501  0.024264  ]
# Cumulative explained variance: 0.9987156635742109
# Processing meter: MAC002965
# Meter MAC002965
# Explained variance ratio: [0.67455144 0.17345945 0.12747497 0.02369768]
# Cumulative explained variance: 0.9991835461303384
# Processing meter: MAC004955
# Meter MAC004955
# Explained variance ratio: [0.64512064 0.20275487 0.13418755 0.01716539]
# Cumulative explained variance: 0.9992284477708051
# Processing meter: MAC005373
# Meter MAC005373
# Explained variance ratio: [0.5604143  0.27267717 0.13377466 0.03153402]
# Cumulative explained variance: 0.9984001531298592
# Processing meter: MAC000647
# Meter MAC000647
# Explained variance ratio: [0.48018518 0.29664968 0.14012947 0.06851059]
# Cumulative explained variance: 0.9854749271189561
# Processing meter: MAC002433
# Meter MAC002433
# Explained variance ratio: [0.48092616 0.29203447 0.13085808 0.05737367]
# Cumulative explained variance: 0.9611923846117882
# Processing meter: MAC004989
# Meter MAC004989
# Explained variance ratio: [0.46593366 0.35128048 0.14342978 0.03642853]
# Cumulative explained variance: 0.9970724469209282
# Processing meter: MAC003212
# Meter MAC003212
# Explained variance ratio: [0.55656226 0.24081501 0.13051551 0.0608796 ]
# Cumulative explained variance: 0.9887723724552084
# Processing meter: MAC001869
# Meter MAC001869
# Explained variance ratio: [0.64427733 0.1779575  0.13528509 0.03662282]
# Cumulative explained variance: 0.9941427296190549
# Processing meter: MAC000002
# Meter MAC000002
# Explained variance ratio: [8.21894858e-01 1.35274308e-01 4.23241895e-02 4.70561370e-04]
# Cumulative explained variance: 0.9999639170979735
# Processing meter: MAC002603
# Meter MAC002603
# Explained variance ratio: [0.47259244 0.35101789 0.14226282 0.02932506]
# Cumulative explained variance: 0.9951982049493456
# Processing meter: MAC004263
# Meter MAC004263
# Explained variance ratio: [0.44936321 0.36077109 0.14260232 0.04119534]
# Cumulative explained variance: 0.9939319614376108
# Processing meter: MAC003548
# Meter MAC003548
# Explained variance ratio: [0.60712961 0.21443646 0.12238811 0.05535733]
# Cumulative explained variance: 0.9993115161168967
# Processing meter: MAC000803
# Meter MAC000803
# Explained variance ratio: [0.48795525 0.30516476 0.14162595 0.0538845 ]
# Cumulative explained variance: 0.9886304705170427
# Processing meter: MAC005523
# Meter MAC005523
# Explained variance ratio: [0.56922253 0.23484968 0.13981675 0.05369904]
# Cumulative explained variance: 0.9975880056981734
# Processing meter: MAC002517
# Meter MAC002517
# Explained variance ratio: [0.52849689 0.28044029 0.13396704 0.05446475]
# Cumulative explained variance: 0.9973689756309003
# Processing meter: MAC000768
# Meter MAC000768
# Explained variance ratio: [0.53190078 0.26328432 0.13995177 0.05705964]
# Cumulative explained variance: 0.9921964938007197
# Processing meter: MAC000301
# Meter MAC000301
# Explained variance ratio: [0.5976328  0.22449573 0.12868182 0.04512117]
# Cumulative explained variance: 0.9959315210673225
# Processing meter: MAC004029
# Meter MAC004029
# Explained variance ratio: [0.51667211 0.30195838 0.1389608  0.04068012]
# Cumulative explained variance: 0.9982714066772089
# Processing meter: MAC004026
# Meter MAC004026
# Explained variance ratio: [0.47162272 0.35227182 0.13542525 0.03811468]
# Cumulative explained variance: 0.9974344719071342

# %%
l_tot=0
for meter_measures in all_preds:
  l = meter_measures.shape
  l_tot+=int(l[0])
print(f"Total number of samples in the attacked meters: {l_tot}")
# Out:
# Total number of samples in the attacked meters: 600164

# %%
# Concatenate predictions
y_pred_series = pd.concat(all_preds).sort_index()

# Join predictions to test set
results = extracted_df_test_meter.join(
    y_pred_series.rename('y_pred'),
    how='inner'
)

# Align true values
true_energy = extracted_df_true_y_values_meter.loc[
    results.index,
    'energy(kWh)'
]

# Create target
y_target = np.where(
    np.isclose(true_energy, results['energy(kWh)']),
    1,
    -1
)

# Predictions
y_pred_aligned = results['y_pred']

# Count attacks
n_attacks = np.sum(y_target == -1)

print(f"Actual attacks:")
print(f"{n_attacks}/{len(y_target)} ({round(n_attacks/len(y_target)*100, 2)}%)")
# Out:
# Actual attacks:
# 15246/600164 (2.54%)

# %% [markdown]
# ### Classification results + confusion matrix

# %%
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
from sklearn.metrics import precision_score, recall_score, f1_score
import seaborn as sns

# Convert OCSVM labels: 1=normal, 0=attack
y_pred_bin = (y_pred_aligned == 1).astype(int)
y_true_bin = (y_target == 1).astype(int)

# CONFUSION MATRIX
cm = confusion_matrix(y_true_bin, y_pred_bin)
cm_ratio = cm / cm.sum(axis=1, keepdims=True)

print("Confusion Matrix:")
print(cm)

print("Confusion Matrix (%):")
print(cm_ratio)

# Complete metrics
tn, fp, fn, tp = cm.ravel()

accuracy = accuracy_score(y_true_bin, y_pred_bin)
precision = precision_score(y_true_bin, y_pred_bin)
recall = recall_score(y_true_bin, y_pred_bin)
specificity = tn / (tn + fp)
f1 = f1_score(y_true_bin, y_pred_bin)

print("\nCLASSIFICATION METRICS (ATTACK or NOT):")
print(f"Accuracy:   {accuracy*100:.1f}%")
print(f"Sensitivity: {recall*100:.1f}%")
print(f"Precision:  {precision*100:.1f}%")
print(f"Specificity:{specificity*100:.1f}%")
print(f"F1-Score:   {f1:.4f}")

# Plot
plt.figure(figsize=(10, 4))
# Confusion Matrix heatmap
plt.subplot(1, 2, 1)
sns.heatmap(cm_ratio, annot=True,
            fmt='.3f',
            cmap='Blues',
            xticklabels=['Attack', 'Clean'],
            yticklabels=['Attack', 'Clean'])
plt.title('Confusion Matrix\nADS Cluster 0', fontsize=14, fontweight='bold')
plt.ylabel('True Label')
plt.xlabel('Predicted Label')
# Metrics bar plot
plt.subplot(1, 2, 2)
metrics = ['Accuracy', 'Sensitivity', 'Precision', 'Specificity']
values = [accuracy, recall, precision, specificity]
colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728']
bars = plt.bar(metrics, values, color=colors, alpha=0.8, edgecolor='black')
plt.ylim(0, 1.05)
plt.title('ADS Performance Metrics', fontsize=14, fontweight='bold')
plt.ylabel('Score')

# Numeric values on the bars
for bar, val in zip(bars, values):
    plt.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 0.01,
             f'{val:.3f}', ha='center', va='bottom', fontweight='bold')

plt.tight_layout()
plt.show()
# Out:
# Confusion Matrix:
# [[ 11355   3891]
#  [ 89321 495597]]
# Confusion Matrix (%):
# [[0.74478552 0.25521448]
#  [0.15270688 0.84729312]]
#
# CLASSIFICATION METRICS (ATTACK or NOT):
# Accuracy:   84.5%
# Sensitivity: 84.7%
# Precision:  99.2%
# Specificity:74.5%
# F1-Score:   0.9140

# %%
# Array numpy
y_true = np.array(y_true_bin)
y_pred = np.array(y_pred_bin)

# Indici
x = np.arange(len(y_true))

# Maschere
tp = (y_true == 1) & (y_pred == 1)
tn = (y_true == 0) & (y_pred == 0)
fp = (y_true == 0) & (y_pred == 1)
fn = (y_true == 1) & (y_pred == 0)

plt.figure(figsize=(16,5))

# Corretti
plt.scatter(x[tn], y_true[tn],
            label='True Negative',
            s=15)

plt.scatter(x[tp], y_true[tp],
            label='True Positive',
            s=15)

# Errori
plt.scatter(x[fp], y_true[fp],
            label='False Positive',
            marker='x',
            s=50)

plt.scatter(x[fn], y_true[fn],
            label='False Negative',
            marker='x',
            s=50)

plt.yticks([0,1], ['Normal', 'Attack'])
plt.xlabel("Sample Index")
plt.ylabel("Class")
plt.title("Correct and Incorrect Classifications")
plt.legend()

plt.grid(alpha=0.3)
plt.show()

# %%
# FEATURES

features = [
    'mean_48',
    'std_48',
    'rms_48',
    'crest_factor_48',
    'impulse_factor_48',
    'shape_factor_48',
    'energy_mean_cluster'
]

#ids
_ids = ['MAC004029','MAC000342', 'MAC002517', 'MAC003558', 'MAC001070', 'MAC002606', 'MAC003719', 'MAC003502', 'MAC002621', 'MAC001166']

# GLOBAL PCA SPACE
all_data = pd.concat([
    _df_train_meter[features],
    _df_test_meter[features]
]).dropna()

scaler_global = StandardScaler()
X_all_scaled = scaler_global.fit_transform(all_data)

pca = PCA(n_components=2)
X_all_pca = pca.fit_transform(X_all_scaled)


# COLLECT PLOT DATA
train_normals = []
train_attacks = []
test_normals = []
test_attacks = []


# TRAIN MODELS PER METER
for meter_id in _ids:

    train_meter = _df_train_meter.xs(meter_id, level='LCLid')[features].dropna()
    test_meter = _df_test_meter.xs(meter_id, level='LCLid')[features].dropna()

    scaler = StandardScaler()

    X_train = scaler.fit_transform(train_meter)
    X_test = scaler.transform(test_meter)

    X_train_pca = pca.transform(scaler_global.transform(train_meter))
    X_test_pca = pca.transform(scaler_global.transform(test_meter))

    ocsvm = OneClassSVM(
        kernel='rbf',
        nu=0.1,
        gamma='scale'
    )

    ocsvm.fit(X_train_pca)


    # TRAIN PREDICTIONS
    train_pred = ocsvm.predict(X_train_pca)

    train_normals.append(X_train_pca[train_pred == 1])
    train_attacks.append(X_train_pca[train_pred == -1])


    # TEST PREDICTIONS
    test_pred = ocsvm.predict(X_test_pca)

    test_normals.append(X_test_pca[test_pred == 1])
    test_attacks.append(X_test_pca[test_pred == -1])


# CONCAT ALL
train_normals = np.vstack(train_normals)
train_attacks = np.vstack(train_attacks)
test_normals = np.vstack(test_normals)
test_attacks = np.vstack(test_attacks)


# PLOT
plt.figure(figsize=(14, 10))

# TRAIN NORMAL
plt.scatter(
    train_normals[:, 0],
    train_normals[:, 1],
    s=10,
    alpha=0.4,
    label='Train Normal'
)

# TEST NORMAL
plt.scatter(
    test_normals[:, 0],
    test_normals[:, 1],
    s=15,
    alpha=0.6,
    label='Test Normal'
)

# TRAIN ATTACK (OCSVM OUTLIERS)
plt.scatter(
    train_attacks[:, 0],
    train_attacks[:, 1],
    s=25,
    alpha=0.9,
    marker='x',
    label='Train Outliers'
)

# TEST ATTACK (DETECTED)
plt.scatter(
    test_attacks[:, 0],
    test_attacks[:, 1],
    s=35,
    alpha=1.0,
    marker='x',
    label='Test Anomalies'
)

plt.title("OCSVM Meter-by-Meter (PCA Projection)")
plt.xlabel("PC1")
plt.ylabel("PC2")

plt.legend()
plt.grid(True)

plt.show()
